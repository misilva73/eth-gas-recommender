# %% [markdown]
# # Data gathering - full run for 1 month of data
#
# #### Maria Silva, Feb. 2025
#
# This notebook uses the `data` module in `src` to gather 1 month of mempool data.

# %%
import os
import sys
import pandas as pd

src_dir = os.path.abspath("../src")
sys.path.append(src_dir)

from data import gather_tx_features_for_day_range

# %%
gather_tx_features_for_day_range("2025-01-01", "2025-02-01")
# Out:
#
# Processing features for 2025-01-01...
# ...
# Download complete!
# ...
# Download complete!
# ...
# Download complete!
#
# Processing features for 2025-01-02...
# ...
# Download complete!
#
# Processing features for 2025-01-03...
# ...
# Download complete!
#
# Processing features for 2025-01-04...
# ...
# Download complete!
#
# Processing features for 2025-01-05...
# ...
# Download complete!
#
# Processing features for 2025-01-06...
# ...
# Download complete!
#
# Processing features for 2025-01-07...
# ...
# Download complete!
#
# Processing features for 2025-01-08...
# ...
# Download complete!
#
# Processing features for 2025-01-09...
# ...
# Download complete!
#
# Processing features for 2025-01-10...
# ...
# Download complete!
#
# Processing features for 2025-01-11...
# ...
# Download complete!
#
# Processing features for 2025-01-12...
# ...
# Download complete!
#
# Processing features for 2025-01-13...
# ...
# Download complete!
#
# Processing features for 2025-01-14...
# ...
# Download complete!
#
# Processing features for 2025-01-15...
# ...
# Download complete!
#
# ...
